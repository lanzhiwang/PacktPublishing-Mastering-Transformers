# %% [markdown]
# # transformers

# %%
# !pip freeze > requirements.txt

# %%
import transformers
import torch

# %%
transformers.__version__
# Out:
# '4.48.3'

# %% [markdown]
# # huggingface transformers 支持的模型
#
# 这里的模型指的是`模型结构`, 不是`模型权重`.
#
# * https://huggingface.co/docs/transformers/v4.48.2/en/index#supported-models-and-frameworks
#
# ![image.png](data:image/png;base64,...)
#
# 对于每一种`模型结构`, transformers 提供了一些相关的 `Resources`
# 以 `llama2` 模型结构为例, 提供的相关 `Resources` 如下图所示:
#
# * https://huggingface.co/docs/transformers/model_doc/llama2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## llama2

# %% [markdown]
# * https://huggingface.co/google-bert/bert-base-uncased
